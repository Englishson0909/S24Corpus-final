# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/S24Corpus-final/blob/main/RQs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import pandas as pd
from io import StringIO
import re

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def count_non_blank_words(df):
    """Count all non-blank words in a DataFrame, considering all text columns."""
    # Filter to include only text-based columns if desired (e.g., df.select_dtypes(include=['object']))
    text = ' '.join(df.astype(str).sum())  # Convert all data to string and concatenate
    text = re.sub(r'\s+', ' ', text.strip())  # Strip leading/trailing spaces and replace multiple spaces with single space
    words_list = re.findall(r'\b\w+\b', text.lower())  # Find all words using regex, making it case-insensitive
    return len(words_list)

# URL of the CSV file (use the raw version of the file from GitHub)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'

try:
    # Download the CSV file from GitHub
    df = download_csv(csv_url)

    # Count non-blank words across the entire DataFrame
    non_blank_word_count = count_non_blank_words(df)

    # Output the total non-blank word count
    print(f"Total number of non-blank words in the file: {non_blank_word_count}")
except Exception as e:
    print(e)
# Out:
# Total number of non-blank words in the file: 219507

# %%
import requests
import pandas as pd
from io import StringIO
import re

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def count_non_blank_words(df):
    """Count all non-blank words in a DataFrame, considering all text columns."""
    # Convert each cell to string first to avoid any aggregation issues
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    text = re.sub(r'\s+', ' ', text.strip())  # Clean up any extra spaces
    words_list = re.findall(r'\b\w+\b', text.lower())  # Find all words using regex, making it case-insensitive
    return len(words_list)

# URL of the CSV file (use the raw version of the file from GitHub)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV file from GitHub
    df = download_csv(csv_url)

    # Count non-blank words across the entire DataFrame
    non_blank_word_count = count_non_blank_words(df)

    # Output the total non-blank word count
    print(f"Total number of non-blank words in the file: {non_blank_word_count}")
except Exception as e:
    print(e)
# Out:
# Total number of non-blank words in the file: 219507

# %% [markdown]
# RQ1
# How does the frequency of the adverb "very" differ between written and spoken texts?

# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import pandas as pd
from io import StringIO
import re

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def count_specific_word(df, word):
    """Count occurrences of a specific word in a DataFrame, considering all text columns."""
    # Convert each cell to string first to avoid any aggregation issues
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    text = re.sub(r'\s+', ' ', text.strip())  # Clean up any extra spaces
    words_list = re.findall(r'\b{}\b'.format(re.escape(word.lower())), text.lower())  # Find all instances of the word
    return len(words_list)

# URL of the CSV file (use the raw version of the file from GitHub)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV file from GitHub
    df = download_csv(csv_url)

    # Count occurrences of the word "very" across the entire DataFrame
    word_to_count = "very"
    word_count = count_specific_word(df, word_to_count)

    # Output the total word count
    print(f"The word '{word_to_count}' appears {word_count} times in the CSV.")
except Exception as e:
    print(e)
# Out:
# The word 'very' appears 201 times in the CSV.

# %%
import requests
import pandas as pd
from io import StringIO
import re

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def count_specific_word(df, word):
    """Count occurrences of a specific word in a DataFrame, considering all text columns."""
    # Convert each cell to string first to avoid any aggregation issues
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    text = re.sub(r'\s+', ' ', text.strip())  # Clean up any extra spaces
    words_list = re.findall(r'\b{}\b'.format(re.escape(word.lower())), text.lower())  # Find all instances of the word
    return len(words_list)

# URL of the CSV file (use the raw version of the file from GitHub)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'

try:
    # Download the CSV file from GitHub
    df = download_csv(csv_url)

    # Count occurrences of the word "very" across the entire DataFrame
    word_to_count = "very"
    word_count = count_specific_word(df, word_to_count)

    # Output the total word count
    print(f"The word '{word_to_count}' appears {word_count} times in the CSV.")
except Exception as e:
    print(e)
# Out:
# The word 'very' appears 465 times in the CSV.

# %%
pip install matplotlib pandas
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data: replace these with your actual data
data = {
    'Metric': ['Frequency of very'],
    'TED': [465],
    'COCA': [201]
}

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
fig, ax = plt.subplots()
# Set position of bar on X axis
x = df.index
width = 0.35  # width of the bars

# Make the plot
rects1 = ax.bar(x - width/2, df['TED'], width, label='TED')
rects2 = ax.bar(x + width/2, df['COCA'], width, label='COCA')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Values')
ax.set_title('Comparison between TED and COCA metrics')
ax.set_xticks(x)
ax.set_xticklabels(df['Metric'])
ax.legend()

# Attach a text label above each bar in *rects*, displaying its height.
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# RQ 2 	What are the distributional patterns of "very" as an adverb, adjective, and noun in written and spoken text?

# %%
import requests
import pandas as pd
import re
import spacy
from io import StringIO
from collections import Counter

# Load SpaCy English model
nlp = spacy.load('en_core_web_sm')

# Increase the maximum length limit for SpaCy
nlp.max_length = 1500000

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        try:
            # Attempt to read the CSV with the default settings
            df = pd.read_csv(csv_raw)
        except pd.errors.ParserError:
            # If default settings fail, attempt to read with a different delimiter
            csv_raw.seek(0)
            df = pd.read_csv(csv_raw, delimiter=',', error_bad_lines=False)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    text = re.sub(r'\s+', ' ', text.strip())  # Clean up any extra spaces
    return text

def analyze_very_in_chunks(text, chunk_size=100000):
    """Analyze the distribution of 'very' in the text by processing in chunks."""
    pos_counts = Counter()
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        doc = nlp(chunk)
        for token in doc:
            if token.text.lower() == 'very':
                pos_counts[token.pos_] += 1
    return pos_counts

# URL of the CSV file (use the raw version of the file from GitHub)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV file from GitHub
    df = download_csv(csv_url)

    # Extract text from the DataFrame
    text = extract_text(df)

    # Analyze the distribution of 'very' in chunks
    pos_counts = analyze_very_in_chunks(text)

    # Output the results
    print(f"Distribution of 'very' in the text: {pos_counts}")
except Exception as e:
    print(e)
# Out:
# Distribution of 'very' in the text: Counter({'ADV': 193, 'ADJ': 8})

# %%
import requests
import pandas as pd
import re
import spacy
import matplotlib.pyplot as plt
from io import StringIO
from collections import Counter

# Load SpaCy English model
nlp = spacy.load('en_core_web_sm')

# Increase the maximum length limit for SpaCy
nlp.max_length = 1500000

def download_csv(url):
    """GitHub URL로부터 CSV 파일을 다운로드하고 pandas DataFrame으로 반환합니다."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """DataFrame의 모든 열에서 텍스트를 추출하고 결합합니다."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    text = re.sub(r'\s+', ' ', text.strip())  # 여분의 공백 제거
    return text

def analyze_very(text):
    """텍스트에서 'very'의 품사 분포를 분석합니다."""
    doc = nlp(text)
    pos_counts = Counter()
    for token in doc:
        if token.text.lower() == 'very':
            pos_counts[token.pos_] += 1
    return pos_counts

def plot_pos_distribution(pos_counts):
    """'very'의 품사 분포를 시각화합니다."""
    labels, values = zip(*pos_counts.items())
    plt.figure(figsize=(10, 6))
    plt.bar(labels, values, color='blue')
    plt.xlabel('POS Tags')
    plt.ylabel('Frequency')
    plt.title('Distribution of POS Tags for "very"')
    plt.show()

# GitHub의 CSV 파일 URL (raw 버전 사용)
csv_url = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'

try:
    # GitHub에서 CSV 파일 다운로드
    df = download_csv(csv_url)

    # DataFrame의 모든 텍스트를 소문자로 변환
    df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

    # DataFrame에서 텍스트 추출
    text = extract_text(df)

    # 'very'의 품사 분포 분석
    pos_counts = analyze_very(text)

    # 결과 출력
    print(f"Distribution of 'very' in the text: {pos_counts}")

    # 품사 분포 시각화
    plot_pos_distribution(pos_counts)
except Exception as e:
    print(e)
# Out:
# Distribution of 'very' in the text: Counter({'ADV': 450, 'ADJ': 15})

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data for main categories
main_categories = ['TED', 'COCA']
main_values = [10, 15]

# Example data for subcategories under 'TED' and 'COCA'
ted_subcategories = ['Adverb', 'Adjective']
ted_values = [465, 15]

coca_subcategories = ['Adverb', 'Adjective']
coca_values = [193, 8]

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(10, 6))

# Plot main categories
bar_width = 0.4
bar_positions = np.arange(len(main_categories))
ax.bar(bar_positions, main_values, width=bar_width, color='white', label='Main Categories')

# Plot subcategories for 'TED'
ted_positions = bar_positions[0] + np.array([-0.2, 0.2])  # Offsets for subcategories
ax.bar(ted_positions, ted_values, width=bar_width / 2, color=['blue', 'blue'], label='TED Subcategories')

# Plot subcategories for 'COCA'
coca_positions = bar_positions[1] + np.array([-0.2, 0.2])
ax.bar(coca_positions, coca_values, width=bar_width / 2, color=['purple', 'purple'], label='COCA Subcategories')

# Customizing the x-axis to include subcategory labels
all_positions = np.concatenate([ted_positions, coca_positions])
all_labels = ['Adverb (TED)', 'Adjective (TED)', 'Adverb (COCA)', 'Adjective (COCA)']
ax.set_xticks(all_positions)
ax.set_xticklabels(all_labels, rotation=45, ha='right')

# Labels and title
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Bar Plot with Subcategories')

# Add legend
ax.legend()

# Show the plot
plt.tight_layout()  # Adjust layout to make room for x-axis labels
plt.show()

# %% [markdown]
# RQ 3.	Which words are most frequently collocated with "very" in written and spoken texts? (collocation)

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def find_collocations(text, word, top_n=20):
    """Find and return the most common collocations with a given word."""
    tokens = nltk.word_tokenize(text.lower())
    bigram_measures = BigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(tokens)
    finder.apply_freq_filter(3)  # Filter out bigrams that appear less than 3 times
    collocations = finder.ngram_fd.items()
    filtered_collocations = [(ngram, freq) for ngram, freq in collocations if word in ngram]
    sorted_collocations = sorted(filtered_collocations, key=lambda x: x[1], reverse=True)
    return sorted_collocations[:top_n]

def plot_collocations(collocations1, collocations2, word, title1, title2):
    """Plot the most common collocations with a given word for two datasets."""
    collocation_words1 = [' '.join(ngram) for ngram, _ in collocations1]
    frequencies1 = [freq for _, freq in collocations1]

    collocation_words2 = [' '.join(ngram) for ngram, _ in collocations2]
    frequencies2 = [freq for _, freq in collocations2]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))

    axes[0].barh(collocation_words1, frequencies1, color='blue')
    axes[0].set_xlabel('Frequency')
    axes[0].set_ylabel('Collocations')
    axes[0].set_title(title1)
    axes[0].invert_yaxis()

    axes[1].barh(collocation_words2, frequencies2, color='green')
    axes[1].set_xlabel('Frequency')
    axes[1].set_title(title2)
    axes[1].invert_yaxis()

    plt.suptitle(f'Most Common Collocations with "{word}"')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Find the most common collocations with the word "very" in both datasets
    collocations1 = find_collocations(text1, 'very')
    collocations2 = find_collocations(text2, 'very')

    # Output the results
    print(f"Most common collocations with 'very' in the first dataset: {collocations1}")
    print(f"Most common collocations with 'very' in the second dataset: {collocations2}")

    # Plot the collocations
    plot_collocations(collocations1, collocations2, 'very', 'Dataset 1', 'Dataset 2')
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Most common collocations with 'very' in the first dataset: [(('a', 'very'), 68), (('you', 'very'), 36), (('the', 'very'), 35), (('very', 'much'), 33), (('very', 'very'), 25), (('was', 'very'), 23), (('be', 'very'), 21), (('very', 'good'), 19), (('its', 'very'), 18), (('is', 'very'), 18), (('are', 'very'), 17), (('very', 'different'), 17), (('very', 'important'), 14), (('very', 'quickly'), 12), (('not', 'very'), 11), (('very', 'well'), 11), (('very', 'simple'), 8), (('very', 'hard'), 7), (('very', 'first'), 6), (('it', 'very'), 6)]
# Most common collocations with 'very' in the second dataset: [(('a', 'very'), 31), (('is', 'very'), 20), (('the', 'very'), 15), (('be', 'very'), 12), (('was', 'very'), 11), (('very', 'much'), 10), (('are', 'very'), 10), (('very', 'well'), 9), (('s', 'very'), 9), (('very', 'good'), 6), (('very', 'little'), 6), (('very', 'close'), 5), (('very', 'hard'), 5), (('very', 'few'), 4), (('very', 'different'), 4), (('very', 'odd'), 4), (('very', 'serious'), 3), (('very', 'short'), 3), (('very', 'strong'), 3), (('very', 'important'), 3)]

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def find_collocations(text, word, top_n=20):
    """Find and return the most common collocations with a given word."""
    tokens = nltk.word_tokenize(text.lower())
    bigram_measures = BigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(tokens)
    finder.apply_freq_filter(3)  # Filter out bigrams that appear less than 3 times
    collocations = finder.ngram_fd.items()
    filtered_collocations = [(ngram, freq) for ngram, freq in collocations if word in ngram]
    sorted_collocations = sorted(filtered_collocations, key=lambda x: x[1], reverse=True)
    return sorted_collocations[:top_n]

def prepare_combined_data(collocations1, collocations2):
    """Prepare combined data for plotting."""
    colloc_dict = {}

    for ngram, freq in collocations1:
        colloc_word = ' '.join(ngram).replace('very ', '')
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][0] = freq
        else:
            colloc_dict[colloc_word] = [freq, 0]

    for ngram, freq in collocations2:
        colloc_word = ' '.join(ngram).replace('very ', '')
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][1] = freq
        else:
            colloc_dict[colloc_word] = [0, freq]

    return colloc_dict

def plot_combined_collocations(colloc_dict):
    """Plot the combined collocations in a grouped bar plot."""
    labels = colloc_dict.keys()
    dataset1_values = [colloc_dict[label][0] for label in labels]
    dataset2_values = [colloc_dict[label][1] for label in labels]

    x = np.arange(len(labels))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(14, 8))
    rects1 = ax.bar(x - width/2, dataset1_values, width, label='Dataset 1')
    rects2 = ax.bar(x + width/2, dataset2_values, width, label='Dataset 2')

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Collocations')
    ax.set_ylabel('Frequency')
    ax.set_title('Most Common Collocations with "very"')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45, ha='right')
    ax.legend()

    fig.tight_layout()

    plt.show()

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Find the most common collocations with the word "very" in both datasets
    collocations1 = find_collocations(text1, 'very')
    collocations2 = find_collocations(text2, 'very')

    # Prepare combined data for plotting
    combined_colloc_dict = prepare_combined_data(collocations1, collocations2)

    # Plot the combined collocations
    plot_combined_collocations(combined_colloc_dict)
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def find_collocations(text, word, top_n=20):
    """Find and return the most common collocations with a given word followed by another word."""
    tokens = nltk.word_tokenize(text.lower())
    bigram_measures = BigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(tokens)
    finder.apply_freq_filter(3)  # Filter out bigrams that appear less than 3 times
    collocations = finder.ngram_fd.items()
    filtered_collocations = [(ngram, freq) for ngram, freq in collocations if ngram[0] == word]
    sorted_collocations = sorted(filtered_collocations, key=lambda x: x[1], reverse=True)
    return sorted_collocations[:top_n]

def prepare_combined_data(collocations1, collocations2):
    """Prepare combined data for plotting."""
    colloc_dict = {}

    for ngram, freq in collocations1:
        colloc_word = ngram[1]  # Get the word following "very"
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][0] = freq
        else:
            colloc_dict[colloc_word] = [freq, 0]

    for ngram, freq in collocations2:
        colloc_word = ngram[1]
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][1] = freq
        else:
            colloc_dict[colloc_word] = [0, freq]

    return colloc_dict

def plot_combined_collocations(colloc_dict):
    """Plot the combined collocations in a grouped bar plot."""
    labels = colloc_dict.keys()
    dataset1_values = [colloc_dict[label][0] for label in labels]
    dataset2_values = [colloc_dict[label][1] for label in labels]

    x = np.arange(len(labels))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(14, 8))
    rects1 = ax.bar(x - width/2, dataset1_values, width, label='TED')
    rects2 = ax.bar(x + width/2, dataset2_values, width, label='COCA')

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Collocations')
    ax.set_ylabel('Frequency')
    ax.set_title('Most Common Collocations with "very"')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45, ha='right')
    ax.legend()

    fig.tight_layout()

    plt.show()

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Find the most common collocations with the word "very" in both datasets
    collocations1 = find_collocations(text1, 'very')
    collocations2 = find_collocations(text2, 'very')

    # Prepare combined data for plotting
    combined_colloc_dict = prepare_combined_data(collocations1, collocations2)

    # Plot the combined collocations
    plot_combined_collocations(combined_colloc_dict)
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def find_collocations(text, word, top_n=20):
    """Find and return the most common collocations with a given word followed by another word."""
    tokens = nltk.word_tokenize(text.lower())
    bigram_measures = BigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(tokens)
    finder.apply_freq_filter(3)  # Filter out bigrams that appear less than 3 times
    collocations = finder.ngram_fd.items()
    filtered_collocations = [(ngram, freq) for ngram, freq in collocations if ngram[0] == word]
    sorted_collocations = sorted(filtered_collocations, key=lambda x: x[1], reverse=True)
    return sorted_collocations[:top_n]

def prepare_combined_data(collocations1, collocations2):
    """Prepare combined data for plotting."""
    colloc_dict = {}

    for ngram, freq in collocations1:
        colloc_word = ngram[1]  # Get the word following "very"
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][0] = freq
        else:
            colloc_dict[colloc_word] = [freq, 0]

    for ngram, freq in collocations2:
        colloc_word = ngram[1]
        if colloc_word in colloc_dict:
            colloc_dict[colloc_word][1] = freq
        else:
            colloc_dict[colloc_word] = [0, freq]

    return colloc_dict

def plot_combined_collocations(colloc_dict):
    """Plot the combined collocations in a grouped bar plot."""
    labels = list(colloc_dict.keys())
    dataset1_values = [colloc_dict[label][0] for label in labels]
    dataset2_values = [colloc_dict[label][1] for label in labels]

    x = np.arange(len(labels))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(14, 8))
    rects1 = ax.bar(x - width/2, dataset1_values, width, label='Dataset 1')
    rects2 = ax.bar(x + width/2, dataset2_values, width, label='Dataset 2')

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Collocations')
    ax.set_ylabel('Frequency')
    ax.set_title('Most Common Collocations with "very"')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45, ha='right')
    ax.legend()

    fig.tight_layout()

    plt.show()

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'


try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Find the most common collocations with the word "very" in both datasets
    collocations1 = find_collocations(text1, 'very')
    collocations2 = find_collocations(text2, 'very')

    # Prepare combined data for plotting
    combined_colloc_dict = prepare_combined_data(collocations1, collocations2)

    # Plot the combined collocations
    plot_combined_collocations(combined_colloc_dict)
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# RQ4.	What is the relative frequency of other intensifiers in comparison to "very" in written and spoken texts?

# %%
pip install pandas requests nltk matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def count_intensifiers(text, intensifiers):
    """Count the occurrences of each intensifier in the text."""
    tokens = nltk.word_tokenize(text.lower())
    counter = Counter(tokens)
    intensifier_counts = {word: counter[word] for word in intensifiers}
    return intensifier_counts

def plot_intensifier_frequencies(counts1, counts2, title1, title2):
    """Plot the frequencies of intensifiers in two datasets."""
    intensifiers = list(set(list(counts1.keys()) + list(counts2.keys())))
    frequencies1 = [counts1.get(word, 0) for word in intensifiers]
    frequencies2 = [counts2.get(word, 0) for word in intensifiers]

    x = np.arange(len(intensifiers))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(14, 8))
    rects1 = ax.bar(x - width/2, frequencies1, width, label=title1)
    rects2 = ax.bar(x + width/2, frequencies2, width, label=title2)

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Intensifiers')
    ax.set_ylabel('Frequency')
    ax.set_title('Frequency of Intensifiers')
    ax.set_xticks(x)
    ax.set_xticklabels(intensifiers, rotation=45, ha='right')
    ax.legend()

    fig.tight_layout()
    plt.show()

# List of common intensifiers
intensifiers = ['very', 'extremely', 'quite', 'really', 'so', 'too', 'absolutely', 'highly', 'incredibly']

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Count intensifiers in both texts
    intensifier_counts1 = count_intensifiers(text1, intensifiers)
    intensifier_counts2 = count_intensifiers(text2, intensifiers)

    # Plot the intensifier frequencies
    plot_intensifier_frequencies(intensifier_counts1, intensifier_counts2, 'TED', 'COCA')
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def count_intensifiers(text, intensifiers):
    """Count the occurrences of each intensifier in the text."""
    tokens = nltk.word_tokenize(text.lower())
    counter = Counter(tokens)
    intensifier_counts = {word: counter[word] for word in intensifiers}
    return intensifier_counts

def plot_intensifier_frequencies(counts1, counts2, title1, title2):
    """Plot the frequencies of intensifiers in two datasets."""
    intensifiers = list(set(list(counts1.keys()) + list(counts2.keys())))
    frequencies1 = [counts1.get(word, 0) for word in intensifiers]
    frequencies2 = [counts2.get(word, 0) for word in intensifiers]

    x = np.arange(len(intensifiers))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(14, 8))
    rects1 = ax.bar(x - width/2, frequencies1, width, label=title1)
    rects2 = ax.bar(x + width/2, frequencies2, width, label=title2)

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Intensifiers')
    ax.set_ylabel('Frequency')
    ax.set_title('Frequency of Intensifiers')
    ax.set_xticks(x)
    ax.set_xticklabels(intensifiers, rotation=45, ha='right')

    # Annotate bars with their frequencies
    for rects in [rects1, rects2]:
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{int(height)}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    ax.legend()
    fig.tight_layout()
    plt.show()

# List of common intensifiers
intensifiers = ['very', 'extremely', 'quite', 'really', 'so', 'too', 'absolutely', 'highly', 'incredibly']

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'


try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Count intensifiers in both texts
    intensifier_counts1 = count_intensifiers(text1, intensifiers)
    intensifier_counts2 = count_intensifiers(text2, intensifiers)

    # Plot the intensifier frequencies
    plot_intensifier_frequencies(intensifier_counts1, intensifier_counts2, 'TED', 'COCA')
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install pandas requests nltk
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
from collections import Counter

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def count_intensifiers(text, intensifiers):
    """Count the occurrences of each intensifier in the text."""
    tokens = nltk.word_tokenize(text.lower())
    counter = Counter(tokens)
    intensifier_counts = {word: counter[word] for word in intensifiers}
    return intensifier_counts

def create_intensifier_table(counts1, counts2, title1, title2):
    """Create a table comparing the frequencies of intensifiers in two datasets."""
    intensifiers = list(set(list(counts1.keys()) + list(counts2.keys())))
    frequencies1 = [counts1.get(word, 0) for word in intensifiers]
    frequencies2 = [counts2.get(word, 0) for word in intensifiers]

    table_data = {
        'Intensifier': intensifiers,
        title1: frequencies1,
        title2: frequencies2
    }

    df_table = pd.DataFrame(table_data)
    return df_table

# List of common intensifiers
intensifiers = ['very', 'extremely', 'quite', 'really', 'so', 'too', 'absolutely', 'highly', 'incredibly']

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'
try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Count intensifiers in both texts
    intensifier_counts1 = count_intensifiers(text1, intensifiers)
    intensifier_counts2 = count_intensifiers(text2, intensifiers)

    # Create a table comparing the frequencies of intensifiers
    table = create_intensifier_table(intensifier_counts1, intensifier_counts2, 'TED', 'COCA')

    # Display the table
    print(table)
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#   Intensifier   TED  COCA
# 0   extremely    26    15
# 1      highly    16    22
# 2         too   180    87
# 3  absolutely    28    14
# 4        very   465   201
# 5          so  1557   419
# 6      really   487   113
# 7  incredibly    25     3
# 8       quite    66    39

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
from collections import Counter

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def count_specific_words(text, words):
    """Count the occurrences of specific words in the text."""
    tokens = nltk.word_tokenize(text.lower())
    counter = Counter(tokens)
    word_counts = {word: counter[word] for word in words}
    return word_counts

def create_comparison_table(counts1, counts2, title1, title2):
    """Create a table comparing the frequencies of specific words in two datasets."""
    words = list(set(list(counts1.keys()) + list(counts2.keys())))
    frequencies1 = [counts1.get(word, 0) for word in words]
    frequencies2 = [counts2.get(word, 0) for word in words]

    table_data = {
        'Word': words,
        title1: frequencies1,
        title2: frequencies2
    }

    df_table = pd.DataFrame(table_data)
    return df_table

# List of specific words to compare
words_to_compare = ['very', 'so']

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Count specific words in both texts
    word_counts1 = count_specific_words(text1, words_to_compare)
    word_counts2 = count_specific_words(text2, words_to_compare)

    # Create a table comparing the frequencies of specific words
    table = create_comparison_table(word_counts1, word_counts2, 'TED', 'COCA')

    # Display the table
    print(table)
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    Word   TED  COCA
# 0    so  1557   419
# 1  very   465   201

# %%
import requests
import pandas as pd
import nltk
from io import StringIO
import matplotlib.pyplot as plt
from collections import Counter

# Download NLTK data files (only need to be done once)
nltk.download('punkt')

def download_csv(url):
    """Download a CSV file from a given URL and return it as a pandas DataFrame."""
    response = requests.get(url)
    if response.status_code == 200:
        csv_raw = StringIO(response.text)
        df = pd.read_csv(csv_raw)
        return df
    else:
        raise Exception(f"Failed to download CSV. Status code: {response.status_code}")

def extract_text(df):
    """Extract and combine text from all columns of a DataFrame."""
    text = ' '.join(df.fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1))
    return text

def count_specific_words(text, words):
    """Count the occurrences of specific words in the text."""
    tokens = nltk.word_tokenize(text.lower())
    counter = Counter(tokens)
    word_counts = {word: counter[word] for word in words}
    return word_counts

def create_comparison_table(counts1, counts2, title1, title2):
    """Create a table comparing the frequencies of specific words in two datasets."""
    words = list(set(list(counts1.keys()) + list(counts2.keys())))
    frequencies1 = [counts1.get(word, 0) for word in words]
    frequencies2 = [counts2.get(word, 0) for word in words]

    table_data = {
        'Word': words,
        title1: frequencies1,
        title2: frequencies2
    }

    df_table = pd.DataFrame(table_data)
    return df_table

def plot_comparison_table(df_table, title1, title2):
    """Plot the frequencies of specific words in two datasets."""
    labels = df_table['Word']
    frequencies1 = df_table[title1]
    frequencies2 = df_table[title2]

    x = np.arange(len(labels))  # Label locations
    width = 0.35  # Width of the bars

    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width/2, frequencies1, width, label=title1)
    rects2 = ax.bar(x + width/2, frequencies2, width, label=title2)

    # Add some text for labels, title, and custom x-axis tick labels
    ax.set_xlabel('Words')
    ax.set_ylabel('Frequency')
    ax.set_title('Frequency Comparision of "very" and "so" in TED and COCA')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45, ha='right')

    # Annotate bars with their frequencies
    for rects in [rects1, rects2]:
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{int(height)}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    ax.legend()
    fig.tight_layout()
    plt.show()

# List of specific words to compare
words_to_compare = ['very', 'so']

# URLs of the CSV files (use the raw version of the file from GitHub)
csv_url1 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/TEDcleandata.csv'
csv_url2 = 'https://github.com/Englishson0909/S24Corpus-final/raw/main/finalcocatext.csv'

try:
    # Download the CSV files from GitHub
    df1 = download_csv(csv_url1)
    df2 = download_csv(csv_url2)

    # Extract text from the DataFrames
    text1 = extract_text(df1)
    text2 = extract_text(df2)

    # Count specific words in both texts
    word_counts1 = count_specific_words(text1, words_to_compare)
    word_counts2 = count_specific_words(text2, words_to_compare)

    # Create a table comparing the frequencies of specific words
    table = create_comparison_table(word_counts1, word_counts2, 'TED', 'COCA')

    # Display the table
    print(table)

    # Plot the comparison table
    plot_comparison_table(table, 'TED', 'COCA')
except Exception as e:
    print(e)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    Word   TED  COCA
# 0    so  1557   419
# 1  very   465   201
